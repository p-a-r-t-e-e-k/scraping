# %%
import pandas as pd

# %%
df=pd.read_csv('Inform_1000.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11202 entries, 0 to 11201
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      11202 non-null  int64
#  1   Region          11201 non-null  object
#  2   Provincia       11201 non-null  object
#  3   City            11201 non-null  object
#  4   Grade           11201 non-null  object
#  5   Name Of School  11201 non-null  object
#  6   Address         11201 non-null  object
#  7   Type            11201 non-null  object
#  8   Code            11201 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 787.8+ KB

# %%
# def asd(x):
#     if x!="nan":
#         x=str(x)
#         a = x.split(' ')
#         print(a)
#         b= a.remove(a[-1])
#         print(b,"0000000")
# #         return ','.join(b)

# %%
def rename(name):
    if name!='nan':
        a=name.split(' ')
        a.pop(-1)
#         print(a,"......")
        return ' '.join(a)

# %%
rename("ggl hgh (2)")
# Out:
# 'ggl hgh'

# %%
df=pd.read_csv('Inform_1000.csv',converters={'Grade':rename},index_col="Unnamed: 0",skiprows=[1])

# %%
df
# Out:
#          Region              Provincia    City  \
# 1       Abruzzo    Provincia di Chieti  Altino
# 2       Abruzzo    Provincia di Chieti  Altino
# 3       Abruzzo    Provincia di Chieti  Altino
# 4       Abruzzo    Provincia di Chieti  Altino
# 5       Abruzzo    Provincia di Chieti  Altino
# ...         ...                    ...     ...
# 11197  Campania  Città Metr. di Napoli   Volla
# 11198  Campania  Città Metr. di Napoli   Volla
# 11199  Campania  Città Metr. di Napoli   Volla
# 11200  Campania  Città Metr. di Napoli   Volla
# 11201  Campania  Città Metr. di Napoli   Volla
#
#                                     Grade               Name Of School  \
# 1                    Scuola dell'Infanzia                        Selva
# 2                    Scuola dell'Infanzia         Santa Rita da Cascia
# 3                         Scuola Primaria             Altino Capoluogo
# 4        Scuola Secondaria di primo grado           Altino - IC Casoli
# ...
